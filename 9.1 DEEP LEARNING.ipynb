# %% [markdown]
# ## ANN(ARTIFICIAL NEURAL NETWORKS)
# 1. Input layer
# 2. Hidden layer(processing part)
# 3. Output layer

# %% [markdown]
# weighted sum
# x1.w1b1+x1.w2b2+x1.w3b3..........x1.wnbn=x2
# x2.w1b1+x2.w2b2+x2.w3b3..........x2.wnbn=x3
# ............................................
# cnn model for image training
