# %%
import pickle
import numpy as np
import tensorflow
import keras

# %%
# loading the data from pickle :
#input data
with open(r"C:\Users\ASUS\Desktop\Emotions\data\images.p", 'rb') as f:
    x = pickle.load(f)
#output data
with open(r"C:\Users\ASUS\Desktop\Emotions\data\labels.p", 'rb') as f:
    y = pickle.load(f)

# %%
print ('Images:',x.shape)
print ('Labels:',y.shape)
# Out:
# Images: (16082, 48, 48)
# Labels: (16082,)

# %%
# labelEncoding output
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y
# Out:
# array([0, 0, 0, ..., 4, 4, 4])

# %%
# Stabdardizing the images for CNN Model:
x = x/255
x=x.reshape(-1,48,48,1)   # -1 -> the total number of images in x variable, 1 -> Number of channel in gray scale, 48,48 -> image shape

# %%
# Using one-hot encoding to output column:
from keras.utils import to_categorical
y = to_categorical(y)   # Don't run it multiple times.

# %%
# Splitting Training and testing datas    ( IF THE MODEL NOT GIVES ABOVE 50% ACCURACY RE-RUN FROM THIS SHELL ONCE AGAIN)
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.1)  #0.1 -> 10% data for testing

# %%
print("xtrain:",xtrain.shape)
print("xtest:",xtest.shape)
print("ytrain:",ytrain.shape)
print("ytest:",ytest.shape)
# Out:
# xtrain: (14473, 48, 48, 1)
# xtest: (1609, 48, 48, 1)
# ytrain: (14473, 5)
# ytest: (1609, 5)

# %%
# CNN Model training :
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

# %%
model = Sequential()
# 1st Convolutional Layer:
model.add(Conv2D(50, (3, 3), input_shape=(48, 48, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# 2nd Convolutional layer:
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# 3rd Convolutional layer:
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Adding flatten Layer: converts 2D to 1D
model.add(Flatten())

# Hidden Layer:
model.add(Dense(256, activation='relu'))  # 256 number of neurones

# Output Layer:
model.add(Dense(5, activation='softmax'))
model.compile(Adam(learning_rate=0.001),loss = 'categorical_crossentropy', metrics =['accuracy'])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Model summary printing:
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 50)          │             500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 50)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 64)          │          28,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         262,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │           1,285 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 329,977 (1.26 MB)
#  Trainable params: 329,977 (1.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(xtrain,ytrain,epochs=15,validation_data=(xtest,ytest))
# Out:
# Epoch 1/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 30s 58ms/step - accuracy: 0.2926 - loss: 1.5461 - val_accuracy: 0.4587 - val_loss: 1.3107
# Epoch 2/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 26s 58ms/step - accuracy: 0.4939 - loss: 1.2344 - val_accuracy: 0.5016 - val_loss: 1.2270
# Epoch 3/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.5603 - loss: 1.0938 - val_accuracy: 0.5513 - val_loss: 1.1171
# Epoch 4/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.6074 - loss: 0.9926 - val_accuracy: 0.5705 - val_loss: 1.0658
# Epoch 5/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.6485 - loss: 0.9011 - val_accuracy: 0.5917 - val_loss: 1.0400
# Epoch 6/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.6785 - loss: 0.8259 - val_accuracy: 0.5942 - val_loss: 1.0462
# Epoch 7/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.7043 - loss: 0.7645 - val_accuracy: 0.5842 - val_loss: 1.1094
# Epoch 8/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.7380 - loss: 0.6931 - val_accuracy: 0.5886 - val_loss: 1.0783
# Epoch 9/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 27s 59ms/step - accuracy: 0.7769 - loss: 0.5982 - val_accuracy: 0.6004 - val_loss: 1.1304
# Epoch 10/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 42s 61ms/step - accuracy: 0.8015 - loss: 0.5305 - val_accuracy: 0.5966 - val_loss: 1.2167
# Epoch 11/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 27s 59ms/step - accuracy: 0.8386 - loss: 0.4367 - val_accuracy: 0.5966 - val_loss: 1.2548
# Epoch 12/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 59ms/step - accuracy: 0.8728 - loss: 0.3637 - val_accuracy: 0.5873 - val_loss: 1.4702
# Epoch 13/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.9015 - loss: 0.2831 - val_accuracy: 0.5898 - val_loss: 1.6999
# Epoch 14/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 41s 60ms/step - accuracy: 0.9214 - loss: 0.2268 - val_accuracy: 0.5774 - val_loss: 1.7799
# Epoch 15/15
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 27s 60ms/step - accuracy: 0.9413 - loss: 0.1724 - val_accuracy: 0.5842 - val_loss: 1.9695

# %%
# To save the model for deployment:
# .h5 -> HDF5 File format
# It stores model's optimizer's state(with learning rate), model's architecture, training configurtations, weights.
model.save('Emotion_detection_model_new.h5')
print("Model Saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved
